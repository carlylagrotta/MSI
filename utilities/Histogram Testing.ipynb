# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import matplotlib.mlab as mlab
import numpy as np
import scipy.stats as stats
temp_list = [0.0015254261277339288, 0.005066792238424424, 0.0015151631684547546, 0.006490261194462834, 0.002655590399503801, 0.013102741174647232, 0.0019657356021015194, -0.011077602605456222, -0.009406937752921205, -0.007914694479267122, -0.0013814628488014644, -1.5113142631121022e-09]
mu2=0
sigma2 = .005
plt.figure()
#plt.hist(temp_list,density=True)
n, bins, patches=plt.hist(temp_list,bins='auto',density=True) 
(mu, sigma) = norm.fit(temp_list)
print(mu,sigma)
print(bins)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))

y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)

x2 = np.linspace(mu2 - 3*sigma2, mu2 + 3*sigma2, 100)
plt.plot(x, stats.norm.pdf(x2, mu2, sigma2))
plt.margins(.01)
# Out:
# 0.00021175089229735135 0.006647262254522959
# [-0.0110776  -0.00624153 -0.00140547  0.0034306   0.00826667  0.01310274]

# %%
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.figure()
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.ylabel('pdf')
# Out:
# Text(0,0.5,'pdf')

# %%
.05/2
# Out:
# 0.025

# %%
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
